# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("C:/Users/User/Desktop/Test-core -Dataset.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group C                some college      standard
# 1    female        group B            some high school  free/reduced
# 2      male        group A                some college  free/reduced
# 3      male        group B           bachelor's degree      standard
# 4    female        group C                 high school      standard
# 5    female        group C            some high school  free/reduced
# 6    female        group C                some college  free/reduced
# 7      male        group C          associate's degree  free/reduced
# 8    female        group C                 high school  free/reduced
# 9    female        group B                some college      standard
# 10     male        group A           bachelor's degree  free/reduced
# 11     male        group D            some high school  free/reduced
# 12   female        group B            some high school      standard
# 13   female        group C                some college  free/reduced
# 14     male        group B          associate's degree      standard
# 15     male        group C                 high school  free/reduced
# 16   female        group D                 high school      standard
# 17     male        group D                 high school      standard
# 18     male        group E                 high school      standard
# 19   female        group C            some high school      standard
# 20     male        group E                some college  free/reduced
# 21   female        group C            some high school      standard
# 22   female        group C           bachelor's degree      standard
# 23     male        group B          associate's degree  free/reduced
# 24   female        group C          associate's degree      standard
# 25   female        group C            some high school      standard
# 26   female        group B          associate's degree      standard
# 27   female        group C          associate's degree      standard
# 28     male        group D             master's degree      standard
# 29     male        group B           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 970  female        group A            some high school      standard
# 971  female        group D          associate's degree      standard
# 972  female        group D                some college  free/reduced
# 973    male        group D          associate's degree      standard
# 974  female        group C          associate's degree  free/reduced
# 975    male        group B            some high school      standard
# 976  female        group D          associate's degree      standard
# 977  female        group B          associate's degree      standard
# 978    male        group C                 high school  free/reduced
# 979  female        group C                 high school      standard
# 980  female        group E          associate's degree  free/reduced
# 981    male        group A            some high school      standard
# 982    male        group C           bachelor's degree  free/reduced
# 983  female        group D                some college      standard
# 984    male        group A                some college      standard
# 985    male        group D            some high school      standard
# 986  female        group C           bachelor's degree      standard
# 987  female        group B             master's degree  free/reduced
# 988  female        group B           bachelor's degree      standard
# 989  female        group C          associate's degree      standard
# 990  female        group C                some college      standard
# 991  female        group D            some high school      standard
# 992    male        group C          associate's degree      standard
# 993  female        group B            some high school      standard
# 994    male        group D                 high school  free/reduced
# 995    male        group D                some college      standard
# 996    male        group D             master's degree      standard
# 997  female        group D                some college      standard
# 998    male        group B                 high school      standard
# 999    male        group C                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 0                 completed          77             81             78
# 1                 completed          37             49             46
# 2                 completed          32             37             41
# 3                 completed          88             87             80
# 4                 completed          92             92             93
# 5                 completed          63             75             80
# 6                      none          49             50             45
# 7                      none          81             76             76
# 8                 completed          83             86             89
# 9                 completed          89             98            100
# 10                completed          74             80             70
# 11                completed          43             34             39
# 12                completed          64             65             71
# 13                completed          78             83             81
# 14                     none          88             83             78
# 15                completed          66             77             72
# 16                     none          74             77             76
# 17                     none          54             43             45
# 18                     none          85             69             70
# 19                completed          48             63             69
# 20                     none          56             49             40
# 21                completed          72             84             84
# 22                completed          57             68             66
# 23                     none          63             66             56
# 24                completed          68             73             81
# 25                completed          46             61             66
# 26                     none          65             68             62
# 27                completed          82             96             93
# 28                     none          95             81             84
# 29                completed          84             74             79
# ..                      ...         ...            ...            ...
# 970                    none          59             58             61
# 971                    none          33             41             47
# 972                    none          38             51             50
# 973                    none          74             67             64
# 974                    none          68             80             75
# 975                    none          23             18             16
# 976               completed          56             70             75
# 977               completed          63             80             80
# 978                    none          65             63             58
# 979                    none          78             82             77
# 980                    none          61             59             59
# 981                    none          68             62             58
# 982                    none          74             70             70
# 983                    none          63             63             60
# 984                    none          48             43             36
# 985                    none          59             53             53
# 986                    none          84             98             95
# 987                    none          64             80             76
# 988                    none          69             79             77
# 989               completed          69             88             87
# 990                    none          53             69             66
# 991                    none          68             80             80
# 992                    none          46             47             41
# 993                    none          63             66             66
# 994                    none          61             58             54
# 995                    none          83             82             79
# 996                    none          64             66             64
# 997               completed          50             68             69
# 998                    none          83             80             76
# 999                    none          72             77             74
#
# [1000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.584000      70.249000      69.128000
# std      15.375414      14.684162      15.242242
# min      16.000000      18.000000      16.000000
# 25%      57.000000      61.000000      59.000000
# 50%      68.000000      70.000000      70.000000
# 75%      79.000000      80.250000      80.000000
# max     100.000000     100.000000     100.000000

# %%
df['overall'] = df.sum(axis=1)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C                some college      standard
# 1  female        group B            some high school  free/reduced
# 2    male        group A                some college  free/reduced
# 3    male        group B           bachelor's degree      standard
# 4  female        group C                 high school      standard
#
#   test preparation course  math score  reading score  writing score  overall
# 0               completed          77             81             78      236
# 1               completed          37             49             46      132
# 2               completed          32             37             41      110
# 3               completed          88             87             80      255
# 4               completed          92             92             93      277

# %%
#2. Draw a histogram for overall score of the students
n, bins, patches = plt.hist(x=df["overall"], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Overall Score')
plt.ylabel('Frquency')

# %%
#3. Score 3 separate histograms for math, reading and writing scores.
#Math
plt.hist(df["math score"],bins='auto',alpha=0.7,rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Math Score')
plt.ylabel('Frquency')

# %%
#Reading
plt.hist(df["reading score"],bins='auto',alpha=0.7,rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Reading Score')
plt.ylabel('Frquency')

# %%
#Writing
plt.hist(df["writing score"],bins='auto',alpha=0.7,rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Writing Score')
plt.ylabel('Frquency')

# %%
#4. What is the summary statistics (mean, median, mode, standard deviation, Q1, Q2,Q3) for each gender
df.groupby('gender')['overall'].describe()
# Out:
#         count        mean        std    min     25%    50%     75%    max
# gender
# female  516.0  211.918605  41.471304  100.0  185.75  213.0  242.00  300.0
# male    484.0  201.675620  44.339787   51.0  174.00  200.0  234.25  300.0

# %%
df.groupby('gender').describe()
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      516.0  65.073643  14.948143  21.0  55.0  65.0  75.0  100.0
# male        484.0  70.260331  15.388226  16.0  60.0  70.5  82.0  100.0
#
#        overall              ...   reading score        writing score  \
#          count        mean  ...             75%    max         count
# gender                      ...
# female   516.0  211.918605  ...           83.25  100.0         516.0
# male     484.0  201.675620  ...           78.00  100.0         484.0
#
#
#              mean        std   min   25%   50%   75%    max
# gender
# female  73.337209  14.019080  34.0  64.0  74.0  83.0  100.0
# male    64.640496  15.227022  16.0  55.0  65.0  76.0  100.0
#
# [2 rows x 32 columns]

# %%
#5. What is the summary statistics (mean, median, mode, standard deviation, Q1, Q2,Q3) for each race
df.groupby('race/ethnicity')['overall'].describe()
# Out:
#                 count        mean        std    min    25%    50%     75%  \
# race/ethnicity
# group A          74.0  199.554054  42.232281  110.0  174.0  201.5  229.75
# group B         201.0  204.069652  41.863649   51.0  178.0  204.0  235.00
# group C         309.0  203.631068  41.802253  100.0  176.0  201.0  234.00
# group D         277.0  206.111913  44.151400   83.0  178.0  212.0  236.00
# group E         139.0  224.179856  42.902189  112.0  191.5  223.0  256.00
#
#                   max
# race/ethnicity
# group A         278.0
# group B         287.0
# group C         299.0
# group D         300.0
# group E         300.0

# %%
df.groupby('race/ethnicity').describe()
# Out:
#                math score                                                 \
#                     count       mean        std   min    25%   50%   75%
# race/ethnicity
# group A              74.0  66.770270  14.715147  27.0  57.25  67.5  77.5
# group B             201.0  65.980100  15.031287  16.0  57.00  66.0  76.0
# group C             309.0  65.699029  14.811040  24.0  57.00  67.0  75.0
# group D             277.0  66.880866  15.618768  21.0  56.00  68.0  79.0
# group E             139.0  75.928058  14.446122  40.0  65.50  77.0  86.0
#
#                       overall              ...   reading score         \
#                   max   count        mean  ...             75%    max
# race/ethnicity                             ...
# group A          98.0    74.0  199.554054  ...            78.5   99.0
# group B          97.0   201.0  204.069652  ...            80.0  100.0
# group C         100.0   309.0  203.631068  ...            80.0  100.0
# group D         100.0   277.0  206.111913  ...            80.0  100.0
# group E         100.0   139.0  224.179856  ...            86.0  100.0
#
#                writing score                                                \
#                        count       mean        std   min   25%   50%   75%
# race/ethnicity
# group A                 74.0  65.675676  14.948412  36.0  56.0  65.0  76.0
# group B                201.0  68.383085  14.546048  16.0  60.0  70.0  78.0
# group C                309.0  68.145631  14.913653  31.0  58.0  69.0  79.0
# group D                277.0  69.552347  15.669653  27.0  60.0  71.0  80.0
# group E                139.0  73.381295  15.542087  31.0  64.0  73.0  85.0
#
#
#                   max
# race/ethnicity
# group A          99.0
# group B         100.0
# group C         100.0
# group D         100.0
# group E         100.0
#
# [5 rows x 32 columns]

# %%
#6. Draw box plots for gender and race and analyze the findings
boxplot = df.boxplot(by='gender')

# %%
boxplot = df.boxplot(by='race/ethnicity')

# %%
from sklearn.preprocessing import LabelEncoder
#test preparation
le = LabelEncoder()
le.fit(df["test preparation course"].drop_duplicates()) 
df["test preparation course"] = le.transform(df["test preparation course"])
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C                some college      standard
# 1  female        group B            some high school  free/reduced
# 2    male        group A                some college  free/reduced
# 3    male        group B           bachelor's degree      standard
# 4  female        group C                 high school      standard
#
#    test preparation course  math score  reading score  writing score  overall
# 0                        0          77             81             78      236
# 1                        0          37             49             46      132
# 2                        0          32             37             41      110
# 3                        0          88             87             80      255
# 4                        0          92             92             93      277

# %%
#7. How is the test preparation affecting the math score. Give a visual representation.
g = sns.FacetGrid(df, col="test preparation course")
g = g.map(plt.hist,"math score", color="y")
plt.show()

# %%
#8. How is the test preparation affecting the overall score. Give a visual representation.
g = sns.FacetGrid(df, col="test preparation course")
g = g.map(plt.hist,"overall", color="y")
plt.show()

# %%
#gender
le = LabelEncoder()
le.fit(df["gender"].drop_duplicates()) 
df["gender"] = le.transform(df["gender"])
#race/ethnicity
le = LabelEncoder()
le.fit(df["race/ethnicity"].drop_duplicates()) 
df["race/ethnicity"] = le.transform(df["race/ethnicity"])
#parental level of education
le = LabelEncoder()
le.fit(df["parental level of education"].drop_duplicates()) 
df["parental level of education"] = le.transform(df["parental level of education"])
#lunch
le = LabelEncoder()
le.fit(df["lunch"].drop_duplicates()) 
df["lunch"] = le.transform(df["lunch"])
df.head()
# Out:
#    gender  race/ethnicity  parental level of education  lunch  \
# 0       1               2                            4      1
# 1       0               1                            5      0
# 2       1               0                            4      0
# 3       1               1                            1      1
# 4       0               2                            2      1
#
#    test preparation course  math score  reading score  writing score  overall
# 0                        0          77             81             78      236
# 1                        0          37             49             46      132
# 2                        0          32             37             41      110
# 3                        0          88             87             80      255
# 4                        0          92             92             93      277

# %%
g = sns.FacetGrid(df, col="gender")
g = g.map(plt.hist,"overall", color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="race/ethnicity")
g = g.map(plt.hist,"overall", color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="parental level of education")
g = g.map(plt.hist,"overall", color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="lunch")
g = g.map(plt.hist,"overall", color="y")
plt.show()

# %%
#9. Generate a Linear Regression classifier to predict the oeverall score
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
x = df.drop(['gender','math score','reading score','writing score','overall'], axis = 1)
y = df.overall
x.head()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
#    race/ethnicity  parental level of education  lunch  test preparation course
# 0               2                            4      1                        0
# 1               1                            5      0                        0
# 2               0                            4      0                        0
# 3               1                            1      1                        0
# 4               2                            2      1                        0

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 0)
lr = LinearRegression().fit(x_train,y_train)
clf = LinearRegression()
clf.fit(x_train, y_train)
predicted = clf.predict(x_test)
expected = y_test


y_train_pred = lr.predict(x_train)
rmse=(np.sqrt(mean_squared_error(y_train,y_train_pred)))
r2=r2_score(y_train,y_train_pred)

print("Model performance for set: \n")
print("R2 score is{}".format(r2),'\n')
# Out:
# Model performance for set:
#
# R2 score is0.15993302273944765

# %%
#Create two clusters and three clusters fron the data set. What is your analysis from clustering.
