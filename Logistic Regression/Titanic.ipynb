# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("C:/Users/User/Desktop/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df["Fare"].max()
# Out:
# 512.32920000000001

# %%
df.shape
# Out:
# (891, 12)

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age']=df['Age'].fillna(np.mean(df.Age))
df=df.dropna(subset=['Embarked'])
df.shape
# Out:
# (889, 12)

# %%
df["Sex"]= df["Sex"].replace(['male','female'],[1,0])
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["Embarked"]= df["Embarked"].replace(['C','Q','S'],[1,2,3])
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"Age",bins=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80], color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"Pclass", color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"SibSp", color="y")
plt.show()

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"Parch", color="y")
plt.show()

# %%
c=df['Survived'].groupby(df['Sex']).value_counts()
c
# Out:
# Sex  Survived
# 0    1           231
#      0            81
# 1    0           468
#      1           109
# Name: Survived, dtype: int64

# %%
c.plot(kind='bar',stacked=True,color=['y','b'])

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"Fare", color="y",bins=20)
plt.show()

# %%
g = sns.FacetGrid(df, col="Survived")
g = g.map(plt.hist,"Embarked", color="y",bins=6)
plt.show()

# %%
X = pd.DataFrame(df[["Age","Pclass","Sex","Parch"]])
y=df["Survived"]
X.head()
# Out:
#     Age  Pclass  Sex  Parch
# 0  22.0       3    1      0
# 1  38.0       1    0      0
# 2  26.0       3    0      0
# 3  35.0       1    0      0
# 4  35.0       3    1      0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
    
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.77

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[135  22]
#  [ 39  71]]

# %%
TN, FP    = confusion_matrix[0, 0], confusion_matrix[0, 1]
FN, TP    = confusion_matrix[1, 0], confusion_matrix[1, 1]

# %%
Accuracy = (float(TP+TN)/float(TP+FP+FN+TN))
print('Accuracy:        ',  round(Accuracy,2) ,"\n")
# Out:
# Accuracy:         0.77

# %%
Precision = (float(TP)/float(TP+FP))
print('Precision:        ',  round(Precision,2) ,"\n")
# Out:
# Precision:         0.76

# %%
Recall = (float(TP)/float(TP+FN))
print ('Recall:        ',round(Recall,2))
# Out:
# Recall:         0.65

# %%
Specificity = (float(TN)/float(TN+FP))
print ('Sepcificity:        ',  round(Specificity,2))
# Out:
# Sepcificity:         0.86

# %%
#F1 Score = 2 * Precision * Recall / (Precision + Recall) 
F1Score = (2*Precision*Recall)/(Precision+Recall)
print ('F1 Score        ',  round(F1Score,2) )
# Out:
# F1 Score         0.7
